# %% [markdown]
# # Trabalhando com Datas

# %%
# Importando a Biblioteca Pandas
import pandas as pd

# %%
# Leitura dos Arquivos
df_01 = pd.read_excel("/content/Aracaju.xlsx")
df_02 = pd.read_excel("/content/Fortaleza.xlsx")
df_03 = pd.read_excel("/content/Natal.xlsx")
df_04 = pd.read_excel("/content/Recife.xlsx")
df_05 = pd.read_excel("/content/Salvador.xlsx")

# %%
# Juntando todos os Arquivos
df = pd.concat([df_01, df_02, df_03, df_04, df_05])

# %%
# Criando a Coluna de Receita
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
# Transformando a Coluna de Data em Tipo Inteiro
df["Data"] = df["Data"].astype("int64")

# %%
# Verificando o Tipo de Dado de cada Coluna
df.dtypes
# Out:
# Cidade     object
# Data        int64
# Vendas    float64
# LojaID      int64
# Qtde        int64
# dtype: object

# %%
# Transformando Coluna de Data em Data
df["Data"] = pd.to_datetime(df["Data"])

# %%
# Verificando o Tipo de Dado de cada Coluna
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Agrupamento por Ano
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
# Criando uma Nova Coluna com Ano
df["Ano_Venda"] = df["Data"].dt.year

# %%
# Pegando uma Amostra do Dataset de 5 Linhas
df.sample(10)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda
# 238      Natal 2019-01-03  139.64    1035     1   139.64       2019
# 173      Natal 2019-01-02   31.77    1034     2    63.54       2019
# 1        Natal 2018-11-25  563.00     853     2  1126.00       2018
# 32      Recife 2019-01-01   15.93     982     7   111.51       2019
# 77   Fortaleza 2019-01-01  167.64    1005     1   167.64       2019
# 58      Recife 2019-01-01    8.02     983     2    16.04       2019
# 103     Recife 2019-01-01   41.65     982     3   124.95       2019
# 54       Natal 2018-10-03  373.00     852     4  1492.00       2018
# 126      Natal 2019-01-02   41.69    1036     2    83.38       2019
# 198      Natal 2019-01-02   13.65    1037     3    40.95       2019

# %%
# Extraindo o Mês e o Dia
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
# Pegando uma Amostra do Dataset de 5 Linhas
df.sample(10)# Pegando uma Amostra do Dataset de 5 Linhas
df.sample(10)
# Out:
#         Cidade       Data  Vendas  ...  Ano_Venda  mes_venda  dia_venda
# 125  Fortaleza 2019-03-02   37.60  ...       2019          3          2
# 22      Recife 2019-01-01   39.53  ...       2019          1          1
# 31       Natal 2018-04-03  401.00  ...       2018          4          3
# 42   Fortaleza 2019-01-01   38.71  ...       2019          1          1
# 130      Natal 2019-01-02   59.78  ...       2019          1          2
# 26       Natal 2018-07-20  370.00  ...       2018          7         20
# 171      Natal 2019-01-02  136.45  ...       2019          1          2
# 239   Salvador 2019-01-03  161.41  ...       2019          1          3
# 46      Recife 2019-01-01  239.17  ...       2019          1          1
# 207   Salvador 2019-01-02   46.70  ...       2019          1          2
#
# [10 rows x 9 columns]

# %%
# Retornando a Data mais Antiga
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
# Calculando a Diferença de Dias
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
# Pegando uma Amostra do Dataset de 5 Linhas
df.sample(10)
# Out:
#         Cidade       Data  Vendas  ...  mes_venda  dia_venda  diferenca_dias
# 139      Natal 2019-01-02  169.01  ...          1          2        366 days
# 70   Fortaleza 2019-01-01   79.57  ...          1          1        365 days
# 66    Salvador 2019-01-01   70.20  ...          1          1        365 days
# 95     Aracaju 2018-01-01  127.43  ...          1          1          0 days
# 183   Salvador 2019-01-02  120.23  ...          1          2        366 days
# 205      Natal 2019-01-02  196.09  ...          1          2        366 days
# 53      Recife 2019-01-01   37.05  ...          1          1        365 days
# 12       Natal 2019-02-02  709.00  ...          2          2        397 days
# 165      Natal 2019-01-02   11.54  ...          1          2        366 days
# 83       Natal 2019-01-02   63.66  ...          1          2        366 days
#
# [10 rows x 10 columns]

# %%
# Criando a Coluna de Trimestre
df["trimestre_venda"] = df["Data"].dt.quarter

# %%
# Pegando uma Amostra do Dataset de 5 Linhas
df.sample(5)
# Out:
#        Cidade       Data  ...  semestre_venda  trimestre_venda
# 188  Salvador 2019-01-02  ...               1                1
# 208     Natal 2019-01-02  ...               1                1
# 190  Salvador 2019-01-02  ...               1                1
# 205     Natal 2019-01-02  ...               1                1
# 72      Natal 2018-05-02  ...               2                2
#
# [5 rows x 12 columns]

# %%
# Filtrando as Vendas de 2019 do Mês de Março
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19
# Out:
#         Cidade       Data  Vendas  ...  dia_venda  diferenca_dias  semestre_venda
# 108  Fortaleza 2019-03-02  152.89  ...          2        425 days               1
# 109  Fortaleza 2019-03-02   18.90  ...          2        425 days               1
# 110  Fortaleza 2019-03-02   51.98  ...          2        425 days               1
# 111  Fortaleza 2019-03-02    8.00  ...          2        425 days               1
# 112  Fortaleza 2019-03-02  133.59  ...          2        425 days               1
# ..         ...        ...     ...  ...        ...             ...             ...
# 137   Salvador 2019-03-02   51.66  ...          2        425 days               1
# 138   Salvador 2019-03-02  212.03  ...          2        425 days               1
# 139   Salvador 2019-03-02  169.01  ...          2        425 days               1
# 140   Salvador 2019-03-02   20.79  ...          2        425 days               1
# 141   Salvador 2019-03-02    9.08  ...          2        425 days               1
#
# [121 rows x 11 columns]
